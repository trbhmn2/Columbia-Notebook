# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Import Data and create a Data Frame

# %%
DF = pd.read_csv('Columbia.csv', index_col=0)

# %%
DF.head()
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
#
#                         emp_title emp_length home_ownership  ...  \
# id                                                           ...
# 1077501                       NaN  10+ years           RENT  ...
# 1077430                     Ryder   < 1 year           RENT  ...
# 1077175                       NaN  10+ years           RENT  ...
# 1076863       AIR RESOURCES BOARD  10+ years           RENT  ...
# 1075358  University Medical Group     1 year           RENT  ...
#
# ...

# %%
DF.columns
# Out:
# Index(['member_id', 'CLI', 'term', 'int_rate', 'installment', 'grade',
#        'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'loan_status', 'pymnt_plan', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
# ...

# %%
DF.shape
# Out:
# (100, 69)

# %%
DF.count()
# Out:
# member_id                      100
# CLI                            100
# term                           100
# int_rate                       100
# installment                    100
# grade                          100
# sub_grade                      100
# emp_title                       94
# emp_length                     100
# home_ownership                 100
# annual_inc                     100
# verification_status            100
# loan_status                    100
# pymnt_plan                     100
# desc                            68
# purpose                        100
# title                          100
# zip_code                       100
# addr_state                     100
# dti                            100
# delinq_2yrs                    100
# earliest_cr_line               100
# inq_last_6mths                 100
# mths_since_last_delinq          23
# mths_since_last_record           4
# open_acc                       100
# pub_rec                        100
# ...

# %%
DF.shape
# Out:
# (100, 69)

# %%
missing_columns=['mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint',
       'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
       'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
       'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
       'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl',
       'inq_last_12m']
df = DF.drop(list(missing_columns), axis = 1)
df.loc[:, ['CLI','term','grade']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6d10dc71d44f> in <module>
#       5        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl',
#       6        'inq_last_12m']
# ----> 7 df = DF.drop(list(missing_columns), axis = 1)
#       8 df.loc[:, ['CLI','term','grade']]
#
# NameError: name 'DF' is not defined

# %%
df.shape
# Out:
# (100, 48)

# %%
df.columns
# Out:
# Index(['member_id', 'CLI', 'term', 'int_rate', 'installment', 'grade',
#        'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'loan_status', 'pymnt_plan', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'policy_code', 'application_type', 'acc_now_delinq'],
#       dtype='object')

# %%
print(len(df))
# Out:
# 100

# %%
#len(df.mths_since_last_record)

# %%
#Returns (Rows, Columns) of the dataset
df.shape
# Out:
# (100, 48)

# %%
#df.drop(['title'], axis=1)

# %%
#Returns total count of non NA values for each column 
#df.count()
#emp_title, mths_since_last_delinq ......etc..  columns have NA values

# %%
df['CLI'].mean()
# Out:
# 9986.5

# %%
df.isna().sum()
# Out:
# member_id                      0
# CLI                            0
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# sub_grade                      0
# emp_title                      6
# emp_length                     0
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# loan_status                    0
# pymnt_plan                     0
# desc                          32
# purpose                        0
# title                          0
# zip_code                       0
# addr_state                     0
# dti                            0
# delinq_2yrs                    0
# earliest_cr_line               0
# inq_last_6mths                 0
# mths_since_last_delinq        77
# mths_since_last_record        96
# open_acc                       0
# pub_rec                        0
# revol_bal                      0
# ...

# %%
df.head()
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
#
#                         emp_title emp_length home_ownership  annual_inc  \
# id
# 1077501                       NaN  10+ years           RENT     24000.0
# 1077430                     Ryder   < 1 year           RENT     30000.0
# 1077175                       NaN  10+ years           RENT     12252.0
# 1076863       AIR RESOURCES BOARD  10+ years           RENT     49200.0
# 1075358  University Medical Group     1 year           RENT     80000.0
#
#         verification_status  loan_status pymnt_plan  \
# id
# ...

# %%
#df.info()

# %%
df.shape
# Out:
# (100, 48)

# %%
df.drop('next_pymnt_d',axis=1,inplace=True)    #  df.drop('column_name', axis=1, inplace=True) axis=1 for column , axis=0 for rows  
df=df.drop(columns=['mths_since_last_record'])

# %%
df.shape
# Out:
# (100, 46)

# %%
#Returns distinct count of observations for each column
df.nunique()
# Out:
# member_id                     100
# CLI                            52
# term                            2
# int_rate                       26
# installment                    92
# grade                           6
# sub_grade                      26
# emp_title                      94
# emp_length                     11
# home_ownership                  3
# annual_inc                     67
# verification_status             3
# loan_status                     3
# pymnt_plan                      1
# desc                           68
# purpose                        10
# title                          73
# zip_code                       82
# addr_state                     26
# dti                            99
# delinq_2yrs                     4
# earliest_cr_line               75
# inq_last_6mths                  5
# mths_since_last_delinq         18
# open_acc                       16
# pub_rec                         2
# revol_bal                     100
# ...

# %%
#Returns count of unique values for series(columns in our case)
df['grade'].value_counts()
# Out:
# B    39
# C    20
# A    17
# D    15
# E     5
# F     4
# Name: grade, dtype: int64

# %%
#df['term'].value_counts()

# %%
#Drop columns
df1=df.drop(columns=['collections_12_mths_ex_med', 'policy_code', 'application_type', 'acc_now_delinq'])

# %%
#df1.shape

# %%
#df1.columns

# %%
df.shape
# Out:
# (100, 46)

# %%
#Selects one column data
df['CLI']
# Out:
# id
# 1077501     5000
# 1077430     2500
# 1077175     2400
# 1076863    10000
# 1075358     3000
# 1075269     5000
# 1069639     7000
# 1072053     3000
# 1071795     5600
# 1071570     5375
# 1070078     6500
# 1069908    12000
# 1064687     9000
# 1069866     3000
# 1069057    10000
# 1069759     1000
# 1065775    10000
# 1069971     3600
# 1062474     6000
# 1069742     9200
# 1069740    20250
# 1039153    21000
# 1069710    10000
# 1069700    10000
# 1069559     6000
# 1069697    15000
# 1069800    15000
# 1069657     5000
# 1069799     4000
# 1047704     8500
# 1032111     4375
# 1069539    31825
# 1065420    10000
# 1069591     5000
# 1069530     7000
# 1069522    12400
# 1069361    10800
# 1069357    15000
# 1069356     6000
# 1069346    12500
# 1067573     9600
# 1069506    12000
# 1069314     3000
# 1060578     4400
# 1069469     6000
# 1051117    14000
# 1069465     5000
# 1069283    10000
# 1069287    10000
# 1069453    11000
# 1069248    15000
# 1068120    25600
# ...

# %%
#Selects more than one column data
df[['CLI','term']]
# Out:
#            CLI        term
# id
# 1077501   5000   36 months
# 1077430   2500   60 months
# 1077175   2400   36 months
# 1076863  10000   36 months
# 1075358   3000   60 months
# 1075269   5000   36 months
# 1069639   7000   60 months
# 1072053   3000   36 months
# 1071795   5600   60 months
# 1071570   5375   60 months
# 1070078   6500   60 months
# 1069908  12000   36 months
# 1064687   9000   36 months
# 1069866   3000   36 months
# 1069057  10000   36 months
# 1069759   1000   36 months
# 1065775  10000   36 months
# 1069971   3600   36 months
# 1062474   6000   36 months
# 1069742   9200   36 months
# 1069740  20250   60 months
# 1039153  21000   36 months
# 1069710  10000   36 months
# 1069700  10000   36 months
# 1069559   6000   36 months
# 1069697  15000   36 months
# 1069800  15000   36 months
# 1069657   5000   60 months
# 1069799   4000   36 months
# 1047704   8500   36 months
# 1032111   4375   36 months
# 1069539  31825   36 months
# 1065420  10000   60 months
# ...

# %%
#Filter data based on condition
df[df['CLI']>20000]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1069740    1284848  20250   60 months     15.27       484.63     C        C4
# 1039153    1269083  21000   36 months     12.42       701.73     B        B4
# 1069539    1304608  31825   36 months      7.90       995.82     A        A4
# 1068120    1302485  25600   36 months      9.91       824.96     B        B1
# 1069410    1303652  21000   60 months     19.91       555.33     E        E4
# 1068994    1303432  22075   60 months     17.27       551.84     D        D3
#
#                                   emp_title emp_length home_ownership  \
# id
# 1069740    Archdiocese of Galveston Houston    3 years           RENT
# 1039153                      Osram Sylvania  10+ years           RENT
# 1069539  Audubon Mutual Housing Corporation    5 years       MORTGAGE
# 1068120               City of Santa Monica     9 years           RENT
# ...

# %%
#Filter all rows and 3 columns
#loc() function filters by labels
df.loc[:, ['CLI','term','grade']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f6924999599b> in <module>
#       1 #Filter all rows and 3 columns
#       2 #loc() function filters by labels
# ----> 3 df.loc[:, ['CLI','term','grade']]
#
# NameError: name 'df' is not defined

# %% [markdown]
# Class Exercise

# %%
#Filter all rows and columns from CLI to loan status columns
#df.loc[:, 'CLI':'loan_status']

# %% [markdown]
# -------------------------------------------------------------------------------------------

# %% [markdown]
# Slice by using loc

# %%
#Filters rows based on condition (Grade=F) and all columns
df.loc[df['grade']=='F' ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-74a48232e924> in <module>
#       1 #Filters rows based on condition (Grade=F) and all columns
# ----> 2 df.loc[df['grade']=='F' ]
#
# NameError: name 'df' is not defined

# %% [markdown]
# Slice using iloc

# %%
# iloc() function filters by index.......index starts from zero and ignores last index while filtering
#Filter all rows and 0 to 5 columns in dataframe df
df.iloc[ :,0:5]
# Out:
#          member_id    CLI        term  int_rate  installment
# id
# 1077501    1296599   5000   36 months     10.65       162.87
# 1077430    1314167   2500   60 months     15.27        59.83
# 1077175    1313524   2400   36 months     15.96        84.33
# 1076863    1277178  10000   36 months     13.49       339.31
# 1075358    1311748   3000   60 months     12.69        67.79
# 1075269    1311441   5000   36 months      7.90       156.46
# 1069639    1304742   7000   60 months     15.96       170.08
# 1072053    1288686   3000   36 months     18.64       109.43
# 1071795    1306957   5600   60 months     21.28       152.39
# 1071570    1306721   5375   60 months     12.69       121.45
# 1070078    1305201   6500   60 months     14.65       153.45
# 1069908    1305008  12000   36 months     12.69       402.54
# 1064687    1298717   9000   36 months     13.49       305.38
# 1069866    1304956   3000   36 months      9.91        96.68
# ...

# %% [markdown]
# Class Exercise

# %%
#Filter all rows and 1,4,6 columns
df.iloc[:,[1,4,6]]
# Out:
#            CLI  installment sub_grade
# id
# 1077501   5000       162.87        B2
# 1077430   2500        59.83        C4
# 1077175   2400        84.33        C5
# 1076863  10000       339.31        C1
# 1075358   3000        67.79        B5
# 1075269   5000       156.46        A4
# 1069639   7000       170.08        C5
# 1072053   3000       109.43        E1
# 1071795   5600       152.39        F2
# 1071570   5375       121.45        B5
# 1070078   6500       153.45        C3
# 1069908  12000       402.54        B5
# 1064687   9000       305.38        C1
# 1069866   3000        96.68        B1
# 1069057  10000       325.74        B2
# 1069759   1000        35.31        D1
# 1065775  10000       347.98        C4
# 1069971   3600       109.57        A1
# 1062474   6000       198.46        B3
# 1069742   9200       280.01        A1
# 1069740  20250       484.63        C4
# 1039153  21000       701.73        B4
# 1069710  10000       330.76        B3
# ...

# %%
#Filters rows from 50 to 60 and 1 to 9 columns
df.iloc[50:60,1:10]
# Out:
#            CLI        term  int_rate  installment grade sub_grade  \
# id
# 1069248  15000   36 months      9.91       483.38     B        B1
# 1068120  25600   36 months      9.91       824.96     B        B1
# 1069244   7000   36 months     10.65       228.02     B        B2
# 1069243  12000   36 months     15.96       421.65     C        C5
# 1069238  12000   36 months      9.91       386.70     B        B1
# 1069410  21000   60 months     19.91       555.33     E        E4
# 1068409  16000   60 months     19.91       423.11     E        E4
# 1068487  10000   36 months     12.42       334.16     B        B4
# 1043961  10000   36 months     10.65       325.74     B        B2
# 1068945   7100   36 months     16.77       252.33     D        D2
#
#                      emp_title emp_length home_ownership
# id
# 1069248       Caterpillar Inc.    8 years       MORTGAGE
# 1068120  City of Santa Monica     9 years           RENT
# 1069244     Aerotek Scientific   < 1 year           RENT
# ...

# %% [markdown]
# ****************************************************************

# %% [markdown]
# Grouping and Sorting data

# %%
#Returns Grade column wise count
df.groupby('grade').count()
# Out:
#        member_id  CLI  term  int_rate  installment  sub_grade  emp_title  \
# grade
# A             17   17    17        17           17         17         16
# B             39   39    39        39           39         39         38
# C             20   20    20        20           20         20         19
# D             15   15    15        15           15         15         13
# E              5    5     5         5            5          5          5
# F              4    4     4         4            4          4          3
#
#        emp_length  home_ownership  annual_inc  verification_status  \
# grade
# A              17              17          17                   17
# B              39              39          39                   39
# C              20              20          20                   20
# D              15              15          15                   15
# E               5               5           5                    5
# ...

# %%
#Sorts the dataset based on specified column(default it sorts in ascending order)
df.sort_values(by='CLI')
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1069759    1304871   1000   36 months     16.29        35.31     D        D1
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1069866    1304956   3000   36 months      9.91        96.68     B        B1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# 1069071    1303716   3000   36 months     13.49       101.80     C        C1
# 1072053    1288686   3000   36 months     18.64       109.43     E        E1
# 1069314    1304202   3000   36 months     18.25       108.84     D        D5
# 1068350    1302971   3500   36 months      6.03       106.53     A        A1
# 1069102    1303750   3500   36 months     10.65       114.01     B        B2
# 1069971    1304884   3600   36 months      6.03       109.57     A        A1
# ...

# %%
#Sorts the dataset based on specified column in decending order
df.sort_values(by='int_rate', ascending=False)
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1068575    1303001  15300   60 months     22.06       423.10     F        F4
# 1068416    1302799   7200   60 months     21.67       197.51     F        F3
# 1068906    1303528   8200   60 months     21.28       223.14     F        F2
# 1071795    1306957   5600   60 months     21.28       152.39     F        F2
# 1048390    1279714  18000   60 months     19.91       475.99     E        E4
# 1069410    1303652  21000   60 months     19.91       555.33     E        E4
# 1068409    1302790  16000   60 months     19.91       423.11     E        E4
# 1065674    1299785   8200   60 months     19.42       214.62     E        E3
# 1072053    1288686   3000   36 months     18.64       109.43     E        E1
# 1069314    1304202   3000   36 months     18.25       108.84     D        D5
# 1069043    1303486  13575   60 months     17.58       341.63     D        D4
# ...

# %%
#Returns max CLI based on term column
df.groupby('sub_grade')['CLI'].max()
# Out:
# sub_grade
# A1    10000
# A2    11000
# A3     9600
# A4    31825
# A5    14400
# B1    25600
# B2    12400
# B3    12800
# B4    21000
# B5    13000
# C1    12000
# C2    16425
# C3    17675
# C4    20250
# C5    12000
# D1    12000
# D2    12000
# D3    22075
# D4    13575
# D5     3000
# E1     3000
# E3     8200
# E4    21000
# F2     8200
# F3     7200
# F4    15300
# Name: CLI, dtype: int64

# %%
#  finding the entries between two values....eg: CLI between 20K and 40K

# %%
df[df.CLI.between(20000, 40000)]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1069740    1284848  20250   60 months     15.27       484.63     C        C4
# 1039153    1269083  21000   36 months     12.42       701.73     B        B4
# 1069539    1304608  31825   36 months      7.90       995.82     A        A4
# 1068120    1302485  25600   36 months      9.91       824.96     B        B1
# 1069410    1303652  21000   60 months     19.91       555.33     E        E4
# 1068994    1303432  22075   60 months     17.27       551.84     D        D3
#
#                                   emp_title emp_length home_ownership  \
# id
# 1069740    Archdiocese of Galveston Houston    3 years           RENT
# 1039153                      Osram Sylvania  10+ years           RENT
# 1069539  Audubon Mutual Housing Corporation    5 years       MORTGAGE
# 1068120               City of Santa Monica     9 years           RENT
# ...

# %% [markdown]
# End of Class work  6/30/2021

# %%
#df.groupby('grade')['CLI'].max()
# Out:
# grade
# A    31825
# B    25600
# C    20250
# D    22075
# E    21000
# F    15300
# Name: CLI, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1077501 to 1067874
# Data columns (total 48 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   member_id                   100 non-null    int64
#  1   CLI                         100 non-null    int64
#  2   term                        100 non-null    object
#  3   int_rate                    100 non-null    float64
#  4   installment                 100 non-null    float64
#  5   grade                       100 non-null    object
#  6   sub_grade                   100 non-null    object
#  7   emp_title                   94 non-null     object
#  8   emp_length                  100 non-null    object
#  9   home_ownership              100 non-null    object
#  10  annual_inc                  100 non-null    float64
#  11  verification_status         100 non-null    object
#  12  loan_status                 100 non-null    object
# ...

# %% [raw]
# ________________________________________________________________________-

# %%
#Returns min CLI based on term, grade columns
df.groupby(['term','grade'])['CLI'].min()
# Out:
# term        grade
#  36 months  A        3500
#             B        3000
#             C        2400
#             D        1000
#             E        3000
#  60 months  B        3000
#             C        2500
#             D        5000
#             E        8200
#             F        5600
# Name: CLI, dtype: int64

# %%
df.groupby(['term','grade','sub_grade'])['CLI'].max()
# Out:
# term        grade  sub_grade
#  36 months  A      A1           10000
#                    A2           11000
#                    A3            9600
#                    A4           31825
#                    A5           14400
#             B      B1           25600
#                    B2           12400
#                    B3           10000
#                    B4           21000
#                    B5           12000
#             C      C1           12000
#                    C2           16425
#                    C3           15000
#                    C4           10000
#                    C5           12000
#             D      D1           12000
#                    D2           12000
#                    D5            3000
#             E      E1            3000
#  60 months  B      B2           10000
#                    B3           12800
#                    B5           13000
#             C      C3           17675
#                    C4           20250
# ...

# %%
#Multiple aggregation functions  .....Returns min,max of CLI based on term & grade
df.groupby(['term','grade'])['CLI'].agg([min, max])
# Out:
#                    min    max
# term       grade
#  36 months A      3500  31825
#            B      3000  25600
#            C      2400  16425
#            D      1000  12000
#            E      3000   3000
#  60 months B      3000  13000
#            C      2500  20250
#            D      5000  22075
#            E      8200  21000
#            F      5600  15300

# %%
df.groupby(['sub_grade'])['CLI'].agg([min, max])
# Out:
#              min    max
# sub_grade
# A1          3500  10000
# A2         11000  11000
# A3          4375   9600
# A4          5000  31825
# A5          5000  14400
# B1          3000  25600
# B2          3500  12400
# B3          4000  12800
# B4          6000  21000
# B5          3000  13000
# C1          3000  12000
# C2         10000  16425
# C3          6500  17675
# C4          2500  20250
# C5          2400  12000
# D1          1000  12000
# D2          4400  12000
# D3          8925  22075
# D4         13575  13575
# D5          3000   3000
# E1          3000   3000
# E3          8200   8200
# E4         16000  21000
# F2          5600   8200
# F3          7200   7200
# F4         15300  15300

# %% [markdown]
# 1. Select multiple rows and columns using .loc

# %% [raw]
# By using the loc operator, we can select subsets of rows and columns on the basis of their index label and column name

# %%
#df.loc[:, 'term':'int_rate']

# %%
#df.loc[:, 'member_id':'grade']

# %% [markdown]
# 2.Filter DataFrames by Category

# %% [raw]
# If we want to consider only the data points that are included in one particular category, or sometimes in a selection of categories.
# For a single category, we are able to do this by using the == operator.
# For multiple categories, we have to make use of the isin function.

# %%
#df[df.grade == 'A']

# %%
#df[df.grade == 'A']['CLI'].max()

# %%
df.loc[df['grade'] =='A'].count
# Out:
# <bound method DataFrame.count of          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1075269    1311441   5000   36 months      7.90       156.46     A        A4
# 1069971    1304884   3600   36 months      6.03       109.57     A        A1
# 1069742    1304855   9200   36 months      6.03       280.01     A        A1
# 1032111    1261745   4375   36 months      7.51       136.11     A        A3
# 1069539    1304608  31825   36 months      7.90       995.82     A        A4
# 1069591    1304289   5000   36 months      8.90       158.77     A        A5
# 1069357    1304251  15000   36 months      7.90       469.36     A        A4
# 1067573    1301955   9600   36 months      7.51       298.67     A        A3
# 1069506    1304567  12000   36 months      7.90       375.49     A        A4
# 1069469    1304526   6000   36 months      6.03       182.62     A        A1
# 1069465    1304521   5000   36 months      8.90       158.77     A        A5
# ...

# %%
df[df.grade.isin(['A', 'B','C'])]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# ...            ...    ...         ...       ...          ...   ...       ...
# 1068547    1303150  10500   36 months     12.69       352.23     B        B5
# 1068545    1303147   7000   36 months     11.71       231.54     B        B3
# 1049528    1280928  12800   60 months     11.71       282.86     B        B3
# 1068350    1302971   3500   36 months      6.03       106.53     A        A1
# 1067874    1302235   6000   60 months     12.69       135.57     B        B5
#
# ...

# %% [markdown]
# 3. Filter Data Frames by excluding categories

# %% [raw]
# We can filter our DataFrame by excluding certain categories. We do this by making use of the ~ (tilde) sign, which is the complement operator.

# %%
df[~df.grade.isin(['A','B','C'])]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1072053    1288686   3000   36 months     18.64       109.43     E        E1
# 1071795    1306957   5600   60 months     21.28       152.39     F        F2
# 1069759    1304871   1000   36 months     16.29        35.31     D        D1
# 1069657    1304764   5000   60 months     16.77       123.65     D        D2
# 1069314    1304202   3000   36 months     18.25       108.84     D        D5
# 1060578    1292332   4400   36 months     16.77       156.37     D        D2
# 1069410    1303652  21000   60 months     19.91       555.33     E        E4
# 1068409    1302790  16000   60 months     19.91       423.11     E        E4
# 1068945    1287308   7100   36 months     16.77       252.33     D        D2
# 1068934    1277395   8950   60 months     17.27       223.74     D        D3
# 1068923    1303549   8000   36 months     16.77       284.31     D        D2
# ...

# %% [markdown]
# 4.Rename Columns

# %% [raw]
# We can change the name of certain columns to provide a more business friendly name ....temporary change

# %%
df.rename({'collections_12_mths_ex_med': '# of collections', 'acc_now_delinq': 'Delinquency'}, axis='columns')
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# 1075269    1311441   5000   36 months      7.90       156.46     A        A4
# 1069639    1304742   7000   60 months     15.96       170.08     C        C5
# 1072053    1288686   3000   36 months     18.64       109.43     E        E1
# 1071795    1306957   5600   60 months     21.28       152.39     F        F2
# 1071570    1306721   5375   60 months     12.69       121.45     B        B5
# 1070078    1305201   6500   60 months     14.65       153.45     C        C3
# ...

# %% [markdown]
# 5.Reverse Column order

# %% [raw]
# Reversing the column order, especially when you handle massive datasets.

# %%
df1=df.loc[:, ::-1]

# %%
df1.head(20)
# Out:
#          acc_now_delinq application_type  policy_code  \
# id
# 1077501               0       INDIVIDUAL            1
# 1077430               0       INDIVIDUAL            1
# 1077175               0       INDIVIDUAL            1
# 1076863               0       INDIVIDUAL            1
# 1075358               0       INDIVIDUAL            1
# 1075269               0       INDIVIDUAL            1
# 1069639               0       INDIVIDUAL            1
# 1072053               0       INDIVIDUAL            1
# 1071795               0       INDIVIDUAL            1
# 1071570               0       INDIVIDUAL            1
# 1070078               0       INDIVIDUAL            1
# 1069908               0       INDIVIDUAL            1
# 1064687               0       INDIVIDUAL            1
# 1069866               0       INDIVIDUAL            1
# 1069057               0       INDIVIDUAL            1
# 1069759               0       INDIVIDUAL            1
# ...

# %% [markdown]
# 6.Split a Data Frame into 2 random sets

# %% [raw]
# If we want to split a DataFrame into two random subsets, we can use the sample function. For example, when creating a training and a test set out of the whole data set, we have to create two random subsets.

# %%
df_1 = df.sample(frac=0.7, random_state=999)
#df_2 = df.drop(df_1.index)

# %%
df_1.describe()
# Out:
#           member_id           CLI   int_rate  installment     annual_inc  \
# count  7.000000e+01     70.000000  70.000000    70.000000      70.000000
# mean   1.299028e+06   9570.357143  12.811143   291.042143   55716.345571
# std    1.061860e+04   4701.913912   3.975497   135.846205   27518.537330
# min    1.261745e+06   1000.000000   6.030000    35.310000   12252.000000
# 25%    1.298789e+06   6000.000000  10.095000   164.672500   37389.000000
# 50%    1.303484e+06   9800.000000  12.555000   296.205000   50000.000000
# 75%    1.304280e+06  12300.000000  15.960000   399.607500   71500.000000
# max    1.314167e+06  22075.000000  22.060000   563.530000  150000.000000
#
#              dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# count  70.000000    70.000000       70.000000               16.000000
# mean   13.951143     0.071429        1.028571               35.187500
# std     6.764230     0.310279        1.141718               17.451719
# ...

# %%
df_2.describe()
# Out:
#           member_id           CLI   int_rate  installment     annual_inc  \
# count  3.000000e+01     30.000000  30.000000    30.000000      30.000000
# mean   1.298563e+06  10957.500000  13.508667   330.593000   61906.666667
# std    1.050609e+04   6695.180169   3.933706   214.910421   25672.800244
# min    1.269083e+06   3000.000000   6.030000    67.790000   15000.000000
# 25%    1.299560e+06   6550.000000  10.650000   201.787500   44010.000000
# 50%    1.303153e+06  10000.000000  13.090000   293.610000   60000.000000
# 75%    1.304159e+06  12600.000000  16.567500   406.012500   75000.000000
# max    1.311748e+06  31825.000000  21.670000   995.820000  120000.000000
#
#              dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# count  30.000000    30.000000       30.000000                7.000000
# mean   15.132333     0.100000        0.833333               45.000000
# std     5.744094     0.547723        0.949894               15.916449
# ...

# %% [markdown]
# 7.Create Dummy Variables

# %% [raw]
# We can create dummy variable out of categorical variables. We can do so by making use of the get_dummies function:

# %%
df['grade'].value_counts()
# Out:
# B    39
# C    20
# A    17
# D    15
# E     5
# F     4
# Name: grade, dtype: int64

# %%
pd.get_dummies(df.grade)
# Out:
#          A  B  C  D  E  F
# id
# 1077501  0  1  0  0  0  0
# 1077430  0  0  1  0  0  0
# 1077175  0  0  1  0  0  0
# 1076863  0  0  1  0  0  0
# 1075358  0  1  0  0  0  0
# ...     .. .. .. .. .. ..
# 1068575  0  0  0  0  0  1
# 1049528  0  1  0  0  0  0
# 1068542  0  0  0  1  0  0
# 1068350  1  0  0  0  0  0
# 1067874  0  1  0  0  0  0
#
# [100 rows x 6 columns]

# %% [markdown]
# 8.Concatenate DataFrames

# %% [raw]
# We can combine two DataFrames into one DataFrame that contains all data points. This can be achieved by using the concat function:

# %%
pd.concat([df_1, df_2]).reset_index(drop=True)
# Out:
#     member_id    CLI        term  int_rate  installment grade sub_grade  \
# 0     1296599   5000   36 months     10.65       162.87     B        B2
# 1     1303528   8200   60 months     21.28       223.14     F        F2
# 2     1278806   8500   36 months     11.71       281.15     B        B3
# 3     1304255  10800   36 months      9.91       348.03     B        B1
# 4     1304855   9200   36 months      6.03       280.01     A        A1
# 5     1304679  15000   36 months     14.27       514.64     C        C2
# 6     1303514  14400   36 months      8.90       457.25     A        A5
# 7     1304237  12500   60 months     12.69       282.44     B        B5
# 8     1274517  10000   36 months     10.65       325.74     B        B2
# 9     1294539   6000   36 months     11.71       198.46     B        B3
# 10    1305201   6500   60 months     14.65       153.45     C        C3
# 11    1302790  16000   60 months     19.91       423.11     E        E4
# ...

# %%
pd.concat([df_1, df_2]).reset_index(drop=True).describe()
# Out:
#           member_id           CLI    int_rate  installment     annual_inc  \
# count  1.000000e+02    100.000000  100.000000    100.00000     100.000000
# mean   1.298888e+06   9986.500000   13.020400    302.90740   57573.441900
# std    1.053401e+04   5380.282722    3.956175    163.47233   26999.818922
# min    1.261745e+06   1000.000000    6.030000     35.31000   12252.000000
# 25%    1.298932e+06   6000.000000   10.650000    168.27750   40000.000000
# 50%    1.303455e+06  10000.000000   12.690000    296.20500   50000.000000
# 75%    1.304264e+06  12425.000000   15.960000    404.72500   75000.000000
# max    1.314167e+06  31825.000000   22.060000    995.82000  150000.000000
#
#               dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# count  100.000000   100.000000      100.000000               23.000000
# mean    14.305500     0.080000        0.970000               38.173913
# std      6.469216     0.393893        1.086696               17.264394
# ...

# %% [markdown]
# 9. Top values in a DataFrame

# %%
#We can find the top 5 values for a Series or DataFrame using nlargest()

# %%
dfl = df.nlargest(5,'CLI')

# %%
print(dfl.CLI)
# Out:
# id
# 1069539    31825
# 1068120    25600
# 1068994    22075
# 1039153    21000
# 1069410    21000
# Name: CLI, dtype: int64

# %% [markdown]
# 10.Bottom values in a DataFrame

# %%
dfs = df.nsmallest(3,'CLI')
#print(dfs.member_id, dfs.CLI)
print (dfs['CLI'])
# Out:
# id
# 1069759    1000
# 1077175    2400
# 1077430    2500
# Name: CLI, dtype: int64

# %%
data=pd.concat([df_1, df_2]).reset_index(drop=True)

# %%
data.describe()
# Out:
#           member_id           CLI    int_rate  installment     annual_inc  \
# count  1.000000e+02    100.000000  100.000000    100.00000     100.000000
# mean   1.298888e+06   9986.500000   13.020400    302.90740   57573.441900
# std    1.053401e+04   5380.282722    3.956175    163.47233   26999.818922
# min    1.261745e+06   1000.000000    6.030000     35.31000   12252.000000
# 25%    1.298932e+06   6000.000000   10.650000    168.27750   40000.000000
# 50%    1.303455e+06  10000.000000   12.690000    296.20500   50000.000000
# 75%    1.304264e+06  12425.000000   15.960000    404.72500   75000.000000
# max    1.314167e+06  31825.000000   22.060000    995.82000  150000.000000
#
#               dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# count  100.000000   100.000000      100.000000               23.000000
# mean    14.305500     0.080000        0.970000               38.173913
# std      6.469216     0.393893        1.086696               17.264394
# ...

# %% [markdown]
# 11.ReIndex....

# %%
# if attribute is string we cannot use the sort_values function. Here we can use reindex function

# %%
#df.home_ownership.reindex(['RENT', 'MORTGAGE'])

# %%
df.reindex(['RENT', 'MORTGAGE'])
# Out:
#           member_id  CLI term  int_rate  installment grade sub_grade  \
# id
# RENT            NaN  NaN  NaN       NaN          NaN   NaN       NaN
# MORTGAGE        NaN  NaN  NaN       NaN          NaN   NaN       NaN
#
#          emp_title emp_length home_ownership  annual_inc verification_status  \
# id
# RENT           NaN        NaN            NaN         NaN                 NaN
# MORTGAGE       NaN        NaN            NaN         NaN                 NaN
#
#          loan_status pymnt_plan desc purpose title zip_code addr_state  dti  \
# id
# RENT             NaN        NaN  NaN     NaN   NaN      NaN        NaN  NaN
# MORTGAGE         NaN        NaN  NaN     NaN   NaN      NaN        NaN  NaN
#
#           delinq_2yrs earliest_cr_line  inq_last_6mths  \
# id
# RENT              NaN              NaN             NaN
# MORTGAGE          NaN              NaN             NaN
#
#           mths_since_last_delinq  open_acc  pub_rec  revol_bal  revol_util  \
# id
# ...

# %% [markdown]
# 12.Dectile or divide the sample into 20 etc..... ( for 20 groups...use .05)

# %%
df.CLI.describe(percentiles=np.arange(0, 1, 0.1))
# Out:
# count      100.000000
# mean      9986.500000
# std       5380.282722
# min       1000.000000
# 0%        1000.000000
# 10%       3590.000000
# 20%       5000.000000
# 30%       6850.000000
# 40%       8200.000000
# 50%      10000.000000
# 60%      10200.000000
# 70%      12000.000000
# 80%      14000.000000
# 90%      16042.500000
# max      31825.000000
# Name: CLI, dtype: float64

# %% [markdown]
# 13.Concatenation

# %%
df[(df['grade'] == 'A') | (df['grade'] == 'B')]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# 1075269    1311441   5000   36 months      7.90       156.46     A        A4
# 1071570    1306721   5375   60 months     12.69       121.45     B        B5
# 1069908    1305008  12000   36 months     12.69       402.54     B        B5
# 1069866    1304956   3000   36 months      9.91        96.68     B        B1
# 1069057    1303503  10000   36 months     10.65       325.74     B        B2
# 1069971    1304884   3600   36 months      6.03       109.57     A        A1
# 1062474    1294539   6000   36 months     11.71       198.46     B        B3
# 1069742    1304855   9200   36 months      6.03       280.01     A        A1
# 1039153    1269083  21000   36 months     12.42       701.73     B        B4
# ...

# %%
df[df['sub_grade'].str.contains('A4|A1')]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1075269    1311441   5000   36 months      7.90       156.46     A        A4
# 1069971    1304884   3600   36 months      6.03       109.57     A        A1
# 1069742    1304855   9200   36 months      6.03       280.01     A        A1
# 1069539    1304608  31825   36 months      7.90       995.82     A        A4
# 1069357    1304251  15000   36 months      7.90       469.36     A        A4
# 1069506    1304567  12000   36 months      7.90       375.49     A        A4
# 1069469    1304526   6000   36 months      6.03       182.62     A        A1
# 1069287    1304171  10000   36 months      6.03       304.36     A        A1
# 1068997    1303437  15000   36 months      7.90       469.36     A        A4
# 1068967    1303403   4500   36 months      6.03       136.96     A        A1
# 1068350    1302971   3500   36 months      6.03       106.53     A        A1
#
# ...

# %% [raw]
# 14.For loop

# %%
df.head()
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
#
#                         emp_title emp_length home_ownership  annual_inc  \
# id
# 1077501                       NaN  10+ years           RENT     24000.0
# 1077430                     Ryder   < 1 year           RENT     30000.0
# 1077175                       NaN  10+ years           RENT     12252.0
# 1076863       AIR RESOURCES BOARD  10+ years           RENT     49200.0
# 1075358  University Medical Group     1 year           RENT     80000.0
#
#         verification_status  loan_status pymnt_plan  \
# id
# ...

# %%
count=0
for gr in df['grade']:
    print (count, gr )
    count += 1
# Out:
# 0 B
# 1 C
# 2 C
# 3 C
# 4 B
# 5 A
# 6 C
# 7 E
# 8 F
# 9 B
# 10 C
# 11 B
# 12 C
# 13 B
# 14 B
# 15 D
# 16 C
# 17 A
# 18 B
# 19 A
# 20 C
# 21 B
# 22 B
# 23 B
# 24 B
# 25 B
# 26 C
# 27 D
# 28 B
# 29 B
# 30 A
# 31 A
# 32 C
# 33 A
# 34 C
# 35 B
# 36 B
# 37 A
# 38 B
# 39 B
# 40 A
# 41 A
# 42 D
# 43 D
# 44 A
# 45 B
# 46 A
# 47 B
# 48 A
# 49 A
# 50 B
# 51 B
# 52 B
# 53 C
# 54 B
# 55 E
# 56 E
# 57 B
# 58 B
# 59 D
# 60 B
# 61 D
# 62 C
# 63 D
# 64 B
# 65 B
# 66 D
# 67 C
# 68 F
# 69 C
# 70 D
# 71 D
# 72 C
# 73 D
# 74 A
# 75 C
# 76 C
# 77 F
# 78 A
# 79 E
# 80 D
# 81 C
# 82 B
# 83 A
# 84 B
# 85 B
# 86 D
# 87 B
# 88 D
# 89 C
# 90 B
# 91 B
# 92 E
# 93 B
# 94 B
# 95 F
# 96 B
# 97 D
# 98 A
# 99 B

# %%
count=0
for tr in df['term']:
    print (count, tr )
    count += 1
# Out:
# 0  36 months
# 1  60 months
# 2  36 months
# 3  36 months
# 4  60 months
# 5  36 months
# 6  60 months
# 7  36 months
# 8  60 months
# 9  60 months
# 10  60 months
# 11  36 months
# 12  36 months
# 13  36 months
# 14  36 months
# 15  36 months
# 16  36 months
# 17  36 months
# 18  36 months
# 19  36 months
# 20  60 months
# 21  36 months
# 22  36 months
# 23  36 months
# 24  36 months
# 25  36 months
# 26  36 months
# 27  60 months
# 28  36 months
# 29  36 months
# 30  36 months
# 31  36 months
# 32  60 months
# 33  36 months
# 34  36 months
# 35  36 months
# 36  36 months
# 37  36 months
# 38  36 months
# 39  60 months
# 40  36 months
# 41  36 months
# 42  36 months
# 43  36 months
# 44  36 months
# 45  36 months
# 46  36 months
# 47  36 months
# 48  36 months
# 49  36 months
# 50  36 months
# 51  36 months
# 52  36 months
# 53  36 months
# 54  36 months
# 55  60 months
# 56  60 months
# 57  36 months
# 58  36 months
# 59  36 months
# 60  60 months
# 61  60 months
# 62  60 months
# ...

# %% [markdown]
# 15.Pivot Table

# %%
#Single Index
table = pd.pivot_table(data=df,index=['term'])
table
# Out:
#                      CLI  acc_now_delinq    annual_inc  \
# term
#  36 months   9549.647887               0  58296.481549
#  60 months  11056.034483               0  55803.241379
#
#             collection_recovery_fee  collections_12_mths_ex_med  delinq_2yrs  \
# term
#  36 months                 0.788385                           0     0.056338
#  60 months                27.232793                           0     0.137931
#
#                   dti  inq_last_6mths  installment   int_rate  \
# term
#  36 months  13.969014        0.816901   314.779155  11.657465
#  60 months  15.129310        1.344828   273.842069  16.357241
#
#             last_pymnt_amnt     member_id  mths_since_last_delinq  open_acc  \
# term
#  36 months      2258.706761  1.299108e+06               38.500000  8.718310
#  60 months      3420.770690  1.298351e+06               37.428571  9.068966
#
#              out_prncp  out_prncp_inv  policy_code   pub_rec  recoveries  \
# term
# ...

# %%
#multiple indexes
table = pd.pivot_table(df,index=['term','grade'])
table
# Out:
#                            CLI  acc_now_delinq    annual_inc  \
# term       grade
#  36 months A       9705.882353               0  66378.893529
#            B      10041.935484               0  58440.258065
#            C      10344.642857               0  49614.000000
#            D       6737.500000               0  57045.625000
#            E       3000.000000               0  48000.000000
#  60 months B       8396.875000               0  46099.500000
#            C      10654.166667               0  45249.000000
#            D      12860.714286               0  55286.285714
#            E      15800.000000               0  79000.000000
#            F       9075.000000               0  68750.000000
#
#                   collection_recovery_fee  collections_12_mths_ex_med  \
# term       grade
#  36 months A                     0.062941                           0
#            B                     1.459848                           0
# ...

# %%
#multiple indexes with different aggregate functions

table = pd.pivot_table(df,index=['term','grade'],aggfunc={'annual_inc':np.mean,'CLI':np.sum})
table
# Out:
#                      CLI    annual_inc
# term       grade
#  36 months A      165000  66378.893529
#            B      311300  58440.258065
#            C      144825  49614.000000
#            D       53900  57045.625000
#            E        3000  48000.000000
#  60 months B       67175  46099.500000
#            C       63925  45249.000000
#            D       90025  55286.285714
#            E       63200  79000.000000
#            F       36300  68750.000000

# %%
table = pd.pivot_table(df,index=['int_rate'],columns=['grade'],values=['CLI'],aggfunc=np.mean)
table
# Out:
#                    CLI                                                     \
# grade                A             B             C        D             E
# int_rate
# 6.03       6133.333333           NaN           NaN      NaN           NaN
# 6.62      11000.000000           NaN           NaN      NaN           NaN
# 7.51       6987.500000           NaN           NaN      NaN           NaN
# 7.90      15765.000000           NaN           NaN      NaN           NaN
# 8.90       8133.333333           NaN           NaN      NaN           NaN
# 9.91               NaN  13628.571429           NaN      NaN           NaN
# 10.65              NaN   8309.090909           NaN      NaN           NaN
# 11.71              NaN   8037.500000           NaN      NaN           NaN
# 12.42              NaN  11550.000000           NaN      NaN           NaN
# 12.69              NaN   9019.444444           NaN      NaN           NaN
# ...

# %%
table.plot(kind='bar');

# %% [markdown]
# 16. Quick plots using Pandas itself

# %% [raw]
# Applying plot function

# %%
df.CLI.plot(kind='hist',title='CLI',figsize=(8,5))
# Out:
# <AxesSubplot:title={'center':'CLI'}, ylabel='Frequency'>

# %%
df.plot(x='int_rate', y='CLI',kind='scatter', title='Interest Rate vs CLI',figsize=(9,6))
# Out:
# <AxesSubplot:title={'center':'Interest Rate vs CLI'}, xlabel='int_rate', ylabel='CLI'>

# %% [markdown]
# 17. Convert data types to appropraite ones

# %%
df.dtypes
# Out:
# member_id                       int64
# CLI                             int64
# term                           object
# int_rate                      float64
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# loan_status                    object
# pymnt_plan                     object
# desc                           object
# purpose                        object
# title                          object
# zip_code                       object
# addr_state                     object
# dti                           float64
# delinq_2yrs                     int64
# earliest_cr_line               object
# inq_last_6mths                  int64
# mths_since_last_delinq        float64
# open_acc                        int64
# ...

# %% [raw]
# Many columns are termed 'object'...they can be converted to appropriate ones by convert_dtypes

# %%
df_new= df.convert_dtypes()

# %%
df_new.dtypes
# Out:
# member_id                       Int64
# CLI                             Int64
# term                           string
# int_rate                      float64
# installment                   float64
# grade                          string
# sub_grade                      string
# emp_title                      string
# emp_length                     string
# home_ownership                 string
# annual_inc                    float64
# verification_status            string
# loan_status                    string
# pymnt_plan                     string
# desc                           string
# purpose                        string
# title                          string
# zip_code                       string
# addr_state                     string
# dti                           float64
# delinq_2yrs                     Int64
# earliest_cr_line               string
# inq_last_6mths                  Int64
# mths_since_last_delinq          Int64
# open_acc                        Int64
# ...

# %% [markdown]
# 18. Display as many rows as you want to see.....

# %% [raw]
# (the default is 60...  more rows means the mid rows will not be shown)

# %%
pd.options.display.max_rows= 100

# %%
df
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# 1075269    1311441   5000   36 months      7.90       156.46     A        A4
# 1069639    1304742   7000   60 months     15.96       170.08     C        C5
# 1072053    1288686   3000   36 months     18.64       109.43     E        E1
# 1071795    1306957   5600   60 months     21.28       152.39     F        F2
# 1071570    1306721   5375   60 months     12.69       121.45     B        B5
# 1070078    1305201   6500   60 months     14.65       153.45     C        C3
# ...

# %% [markdown]
# 19. Set maximum number of columns

# %% [raw]
# default number of columns is 20....

# %%
pd.options.display.max_columns=50

# %%
df
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# 1075269    1311441   5000   36 months      7.90       156.46     A        A4
# 1069639    1304742   7000   60 months     15.96       170.08     C        C5
# 1072053    1288686   3000   36 months     18.64       109.43     E        E1
# 1071795    1306957   5600   60 months     21.28       152.39     F        F2
# 1071570    1306721   5375   60 months     12.69       121.45     B        B5
# 1070078    1305201   6500   60 months     14.65       153.45     C        C3
# ...

# %% [markdown]
# 20.Functions

# %% [raw]
# To create something that doesn't need to be changed every time to run. You do not have to change numbers or variables to get the outcome you desire

# %% [raw]
# Before you  declare a function, create lines of code that will work when not in a function.
# eg:I want to add all the numbers from zero to ten first.

# %%
numbers= sum(range(0,10))
numbers
# Out:
# 45

# %% [raw]
# Define the function

# %%
def numbers(i):
    if i>0:
       total = sum(range(0,i+1)) 
    return total

# %%
numbers(10)
# Out:
# 55

# %%
numbers(20)
# Out:
# 210

# %% [markdown]
# 21.Lambda function

# %%
mean = lambda x : sum(x) / len(x)
x = [5, 10, 15, 20,25]
print(mean(x))
# Out:
# 15.0

# %%
print(mean(df['CLI']))
# Out:
# 9986.5

# %% [raw]
# 22. Math FUnctions

# %%
import math
math.log(1024, 2)
# Out:
# 10.0

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %% [raw]
# https://docs.python.org/3/library/math.html

# %% [raw]
# 23. Statistical Functions

# %%
import statistics as st
st.mean(df['CLI']), st.median(df['CLI'])
# Out:
# (9986.5, 10000.0)

# %% [raw]
# https://docs.python.org/3/library/statistics.html

# %% [raw]
# 24. Date Time function

# %% [raw]
#  can construct date-time types and work with the typical date-time syntax with properties like year, month, and day. This is incredibly useful for re-formatting, parsing, and working with individual sections of dates within your data.

# %%
import datetime as dt
now = dt.date.today()
print(now.year)
print(now.month)
# Out:
# 2021
# 3

# %% [raw]
# 25.Export Data

# %% [markdown]
# Export Data

# %% [raw]
# Any variable name can be used. Different file formats of data can be imported and exported like Excel, Html, JSON, etc.

# %%
#Exporting data
df1.to_csv('reversed dataframe.csv')

# %% [markdown]
# # Import  and Export Financial Data

# %%
#from urllib.parse import urlencode
pd.core.common.is_list_like = pd.api.types.is_list_like
from pandas_datareader import data

# %%
# get the Apple stock data
AAPL= data.DataReader("AAPL", start='2000-1-1',end='2021-06-20',data_source='yahoo')
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-26-1cb7ea58434d> in <module>
#       1 # get the Apple stock data
# ----> 2 AAPL= data.DataReader("AAPL", start='2000-1-1',end='2021-06-20',data_source='yahoo')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     382             retry_count=retry_count,
#     383             pause=pause,
# --> 384             session=session,
#     385         ).read()
#     386
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
# ...

# %%
AAPL.tail(10)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-09-04  123.699997  110.889999  120.070000  120.959999  332607200.0
# 2020-09-08  118.989998  112.680000  113.949997  112.820000  231366600.0
# 2020-09-09  119.139999  115.260002  117.260002  117.320000  176940500.0
# 2020-09-10  120.500000  112.500000  120.360001  113.489998  182274400.0
# 2020-09-11  115.230003  110.000000  114.570000  112.000000  180860300.0
# 2020-09-14  115.930000  112.800003  114.720001  115.360001  140150100.0
# 2020-09-15  118.830002  113.610001  118.330002  115.540001  184642000.0
# 2020-09-16  116.000000  112.040001  115.230003  112.129997  154679000.0
# 2020-09-17  112.199997  108.709999  109.720001  110.339996  178011000.0
# 2020-09-18  110.879997  106.089996  110.400002  106.839996  287104900.0
#
#              Adj Close
# Date
# 2020-09-04  120.367050
# 2020-09-08  112.266953
# 2020-09-09  116.744888
# 2020-09-10  112.933670
# 2020-09-11  111.450974
# ...

# %%
AAPL.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  5212.000000  5212.000000  5212.000000  5212.000000  5.212000e+03
# mean     17.514353    17.150432    17.334002    17.339077  4.498105e+08
# std      21.045704    20.564189    20.808284    20.815442  3.919456e+08
# min       0.235536     0.227143     0.231964     0.234286  3.934000e+07
# 25%       1.339107     1.297321     1.316116     1.323750  1.811698e+08
# 50%       8.996072     8.739286     8.876964     8.856786  3.374112e+08
# 75%      27.330625    26.829999    27.143125    27.112500  5.958813e+08
# max     137.979996   130.529999   137.589996   134.179993  7.421641e+09
#
#          Adj Close
# count  5212.000000
# mean     16.292222
# std      20.497608
# min       0.201805
# 25%       1.140230
# 50%       7.628910
# 75%      25.101121
# max     133.749039

# %%
AAPL.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 2000-01-03  1.004464  0.907924  0.936384  0.999442  535796800.0   0.860883
# 2000-01-04  0.987723  0.903460  0.966518  0.915179  512377600.0   0.788302
# 2000-01-05  0.987165  0.919643  0.926339  0.928571  778321600.0   0.799837
# 2000-01-06  0.955357  0.848214  0.947545  0.848214  767972800.0   0.730621
# 2000-01-07  0.901786  0.852679  0.861607  0.888393  460734400.0   0.765229

# %%
AAPL.to_excel('AAPL.xlsx')

# %%
# get the Microsoft stock data
MSFT= data.DataReader("MSFT", 
                       start='2000-1-1', 
                       end='2020-07-23', 
                       data_source='yahoo')

# %%
MSFT.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  5172.000000  5172.000000  5172.000000  5172.000000  5.172000e+03
# mean     46.414392    45.447000    45.934751    45.941961  5.500155e+07
# std      35.776660    35.030993    35.424048    35.435571  3.138452e+07
# min      15.620000    14.870000    15.200000    15.150000  7.425600e+06
# 25%      26.900000    26.347500    26.623750    26.610001  3.300222e+07
# 50%      30.250000    29.700001    29.977500    29.980000  5.028725e+07
# 75%      47.990002    47.059999    47.552500    47.580002  6.849745e+07
# max     216.380005   211.470001   216.330002   214.320007  5.910522e+08
#
#          Adj Close
# count  5172.000000
# mean     39.410021
# std      37.098476
# min      11.581548
# 25%      18.964647
# 50%      22.283227
# 75%      41.774419
# max     212.754883

# %%
MSFT.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
MSFT.to_csv('MSFT.csv')

# %% [markdown]
# Accessing Yahoo Finance and gathering data

# %%
import yfinance as yf

# %%
tick = yf.Ticker(str('MSFT'))
hist_data = tick.history(period="max")  # Tells yfinance what kind of data we want about this stock (In this example, all of the historical data)
hist_data.tail() # Observe the historical stock data
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2021-06-21  259.82  263.52  257.92  262.63  26696100        0.0           0.0
# 2021-06-22  262.72  265.79  262.40  265.51  24694100        0.0           0.0
# 2021-06-23  265.99  266.83  264.43  265.27  19518700        0.0           0.0
# 2021-06-24  266.16  267.85  265.47  266.69  21446900        0.0           0.0
# 2021-06-25  266.23  267.25  264.76  265.02  25604200        0.0           0.0
