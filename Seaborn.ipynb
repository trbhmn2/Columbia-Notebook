# %%
import numpy as np
import pandas as pd
import seaborn as sns
pd.options.display.max_columns=5
pd.options.display.max_rows=5
DF = pd.read_csv('/Users/23behmen_t/Downloads/Columbia.csv', index_col=0)

# %%
pd.options.display.max_columns=5
pd.options.display.max_rows=5
DF = pd.read_csv('/Users/23behmen_t/Downloads/Columbia.csv', index_col=0)

# %%
DF.isnull().sum()
# Out:
# member_id         0
# CLI               0
#                ...
# total_cu_tl     100
# inq_last_12m    100
# Length: 69, dtype: int64

# %%
DF['mths_since_last_delinq'].fillna(value=(DF['mths_since_last_delinq'].mean()),inplace=True)

# %%
DF['mths_since_last_delinq']
# Out:
# id
# 1077501    38.173913
# 1077430    38.173913
#              ...
# 1068350    35.000000
# 1067874    20.000000
# Name: mths_since_last_delinq, Length: 100, dtype: float64

# %%
sns.scatterplot(x="annual_inc", y="int_rate", hue='grade', data=DF)
# Out:
# <AxesSubplot:xlabel='annual_inc', ylabel='int_rate'>

# %%
sns.boxplot(x="annual_inc", y="int_rate", data=DF)
# Out:
# <AxesSubplot:xlabel='annual_inc', ylabel='int_rate'>

# %%
sns.distplot( DF['annual_inc'], kde=True)
# Out:
# /Users/23behmen_t/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='annual_inc', ylabel='Density'>

# %%
sns.violinplot(x='grade',y='annual_inc', data=DF)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='annual_inc'>

# %%
sns.violinplot(x='grade',y='int_rate', data=DF)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='int_rate'>

# %%
sns.catplot(x="home_ownership", y="CLI", hue="grade",col="term", kind = 'bar',data=DF, palette = "rainbow")

# %%
DF1=DF[['int_rate', 'CLI', 'term','annual_inc']]
print(DF1)
sns.pairplot(DF1,hue='term')
# Out:
#          int_rate   CLI        term  annual_inc
# id
# 1077501     10.65  5000   36 months     24000.0
# 1077430     15.27  2500   60 months     30000.0
# ...           ...   ...         ...         ...
# 1068350      6.03  3500   36 months     83000.0
# 1067874     12.69  6000   60 months     81000.0
#
# [100 rows x 4 columns]

# %%
sns.heatmap(DF1.corr(), fmt = ".2f") #positive means porpotional correlation, negative means unporpotional correlation, 0 means none
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(DF.corr(), fmt = "0.2f")
# Out:
# <AxesSubplot:>
